# %%
import pickle

# %%
with open('eegdata.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
print(data.keys())
# Out:
# dict_keys(['data_encmain', 'data_pre', 'data_proc'])

# %%
import numpy as np

# %%
np.save('data_proc.npy', data['data_proc'])

# %%
np.save('data_pre.npy', data['data_pre'])

# %%
for key in data.keys():
    print(data[key].shape)
# Out:
# (120,)
# (120, 697655)
# (120, 697655)

# %%
data['data_encmain'][0].shape
# Out:
# (697500,)

# %%
a = data['data_encmain']
b = data['data_pre']
c = data['data_proc']

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(a[0][:1000])

# %%
plt.plot(b[0][:1000])

# %%
plt.plot(c[0][:1000])

# %%
plt.plot(a[0][:100000])

# %%
plt.plot(b[0][:100000])

# %%
plt.plot(c[0][:100000])

# %%
a.shape
# Out:
# (120,)

# %%
a[0].shape
# Out:
# (697500,)

# %%
a[118].shape
# Out:
# (697500,)

# %%
a[119].shape
# Out:
# (697345,)

# %%
np.save('data_pre.npy', data['data_pre'])

# %%
np.save('data_proc.npy', data['data_proc'])

# %%
a_cut = [a[i][:697345] for i in range(120)]

# %%
data_enc = np.stack(a_cut)

# %%
data_enc.shape
# Out:
# (120, 697345)

# %%
np.save('data_enc.npy', data_enc)
